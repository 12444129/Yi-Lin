# %% [markdown]
# <a href="https://colab.research.google.com/github/12444129/Yi-Lin/blob/master/A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn import svm
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
import matplotlib
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b468352-41a4-400b-a808-1580a6126284" name="files[]" multiple disabled />
#      <output id="result-9b468352-41a4-400b-a808-1580a6126284">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.txt to data.txt

# %%
df= pd.read_csv('data.txt')
df.head()
# Out:
#                   date  Temperature  Humidity  ...     CO2  HumidityRatio  Occupancy
# 1  2015-02-04 17:51:00        23.18   27.2720  ...  721.25       0.004793          1
# 2  2015-02-04 17:51:59        23.15   27.2675  ...  714.00       0.004783          1
# 3  2015-02-04 17:53:00        23.15   27.2450  ...  713.50       0.004779          1
# 4  2015-02-04 17:54:00        23.15   27.2000  ...  708.25       0.004772          1
# 5  2015-02-04 17:55:00        23.10   27.2000  ...  704.50       0.004757          1
#
# [5 rows x 7 columns]

# %%
df['Temperature'].hist()

# %%
df['Humidity'].hist()

# %%
df['Light'].hist()

# %%
df['CO2'].hist()

# %%
df['HumidityRatio'].hist()

# %%
X = df[['Temperature','Humidity','Light','CO2','HumidityRatio']]
Y = df['Occupancy']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9922226770364306

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="gini")
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9934506753990995

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="entropy", max_depth = 2)
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9889480147359804

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="entropy", max_depth = 5)
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9938600081866558

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="entropy", max_depth = 10)
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9938600081866558

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="entropy", max_depth = 100)
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9909946786737618

# %%
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)
#
#decision tree
clf = tree.DecisionTreeClassifier(criterion="entropy", max_depth = 1000)
clf = clf.fit(X_train, Y_train)
tree.plot_tree(clf.fit(X_train, Y_train)) 
Y_pred = clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9922226770364306
